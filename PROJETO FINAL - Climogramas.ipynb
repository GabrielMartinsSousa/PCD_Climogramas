# %%
import pandas as pd
import os
import glob as gb
import numpy as np
import matplotlib.pyplot as mp
import plotly

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gabriel24036\\Downloads'

# %%
#Criando uma tabela para os dados de uma das cidades
with open("C:\\Users\\raquel24005\\OneDrive - ILUM ESCOLA DE CIÊNCIA\\ILUM\\Prática em Ciências de Dados\\Projeto Final\\INMET_CO_DF_A001_BRASILIA_01-01-2023_A_31-12-2023.CSV", 'r', encoding='utf-8', errors='ignore') as tabela: #encoding define o formato do arquivo, já errors é pra ignorar linhas vazias (sem nada)
    dados = pd.read_csv(tabela, decimal = ',', sep = ";", skiprows = 8) #skiprows -> Pula linhas (do cabeçalho)
dados.describe()
# Out:
#        PRECIPITAO TOTAL, HORRIO (mm)  \
# count                    8755.000000
# mean                        0.113764
# std                         1.015717
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                        23.400000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# count                                        8755.000000
# mean                                          887.618949
# std                                             2.321049
# min                                           879.700000
# 25%                                           886.000000
# 50%                                           887.500000
# 75%                                           889.200000
# max                                           895.800000
#
#        PRESSO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# count                                     8747.000000
# mean                                       887.873202
# std                                          2.294539
# min                                        880.100000
# 25%                                        886.300000
# 50%                                        887.800000
# 75%                                        889.400000
# max                                        895.900000
#
#        PRESSO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# count                                      8747.000000
# mean                                        887.369430
# std                                           2.332279
# min                                         879.700000
# 25%                                         885.700000
# 50%                                         887.300000
# 75%                                         888.900000
# max                                         895.600000
#
#        RADIACAO GLOBAL (Kj/m)  TEMPERATURA DO AR - BULBO SECO, HORARIA (C)  \
# count             4673.000000                                  8755.000000
# mean              1508.103702                                    21.955477
# std               1119.062719                                     4.126353
# min                  0.000000                                     9.600000
# 25%                419.400000                                    19.100000
# 50%               1431.700000                                    21.500000
# 75%               2496.400000                                    24.900000
# max               4083.900000                                    34.400000
#
#        TEMPERATURA DO PONTO DE ORVALHO (C)  \
# count                          8755.000000
# mean                             14.184500
# std                               3.764191
# min                              -1.100000
# 25%                              11.200000
# 50%                              15.300000
# 75%                              17.300000
# max                              21.500000
#
#        TEMPERATURA MXIMA NA HORA ANT. (AUT) (C)  \
# count                               8747.000000
# mean                                  22.735544
# std                                    4.191367
# min                                   10.700000
# 25%                                   19.600000
# 50%                                   22.300000
# 75%                                   25.800000
# max                                   34.600000
#
#        TEMPERATURA MNIMA NA HORA ANT. (AUT) (C)  \
# count                               8747.000000
# mean                                  21.207454
# std                                    4.029440
# min                                    9.400000
# 25%                                   18.500000
# 50%                                   20.800000
# 75%                                   24.000000
# max                                   33.000000
#
#        TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)  \
# count                                      8747.000000
# mean                                         14.816086
# std                                           3.720660
# min                                           0.000000
# 25%                                          12.000000
# 50%                                          16.000000
# 75%                                          17.800000
# max                                          22.300000
#
#        TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)  \
# count                                      8747.000000
# mean                                         13.605751
# std                                           3.799911
# min                                          -1.400000
# 25%                                          10.700000
# 50%                                          14.700000
# 75%                                          16.700000
# max                                          21.300000
#
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               8747.000000
# mean                                  68.326741
# std                                   19.268845
# min                                   19.000000
# 25%                                   54.000000
# 50%                                   70.000000
# 75%                                   86.000000
# max                                   98.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               8747.000000
# mean                                  61.435692
# std                                   19.837790
# min                                   16.000000
# 25%                                   46.000000
# 50%                                   61.000000
# 75%                                   79.000000
# max                                   98.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREO HORARIA (gr) ( (gr))  \
# count                          8755.000000                        8748.000000
# mean                             64.857910                         150.510974
# std                              19.702607                          94.346841
# min                              17.000000                           1.000000
# 25%                              49.000000                          87.000000
# 50%                              66.000000                         119.000000
# 75%                              83.000000                         200.000000
# max                              98.000000                         360.000000
#
#        VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  \
# count                 8747.000000                      8750.000000
# mean                     4.790797                         2.011657
# std                      2.172933                         1.016982
# min                      0.500000                         0.100000
# 25%                      3.000000                         1.200000
# 50%                      4.600000                         1.900000
# 75%                      6.300000                         2.700000
# max                     20.000000                         7.700000
#
#        Unnamed: 19
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
precipitacao_total = dados['PRECIPITAO TOTAL, HORRIO (mm)']

pressao_max = dados['PRESSO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)']
pressao_min = dados['PRESSO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)']
pressao_total = (pressao_max+pressao_min)/2

radiacao_global = dados['RADIACAO GLOBAL (Kj/m)']

temperatura_max = dados['TEMPERATURA MXIMA NA HORA ANT. (AUT) (C)']
temperatura_min = dados['TEMPERATURA MNIMA NA HORA ANT. (AUT) (C)']
temperatura_total = (temperatura_max+temperatura_min)/2

umidade_rel = dados['UMIDADE RELATIVA DO AR, HORARIA (%)']

vento = dados['VENTO, VELOCIDADE HORARIA (m/s)']

# %%
media_precipitacao = np.mean(precipitacao_total)
media_precipitacao
# Out:
# 0.11376356367789836

# %%
media_pressao = np.mean(pressao_total)
media_pressao
# Out:
# 887.6213158797302

# %%
media_radiacao = np.mean(radiacao_global)
media_radiacao
# Out:
# 1508.1037021185534

# %%
media_temperatura = np.mean(temperatura_total)
media_temperatura
# Out:
# 21.971498799588428

# %%
media_umidade = np.mean(umidade_rel)
media_umidade
# Out:
# 64.85790976584809

# %%
media_vento = np.mean(vento)
media_vento
# Out:
# 2.011657142857143

# %%
import pandas as pd

# Carregar os dados do CSV
data = pd.read_csv('Teste_Climograma.csv')
data
# Out:
#    Mês;Temperatura;Precipitação
# 0                      1;32;123
# 1                      2;31;213
# 2                      3;30;153
# 3                      4;30;223
# 4                      5;31;311
# 5                      6;34;164
# 6                      7;33;268
# 7                      8;31;234
# 8                      9;28;165
# 9                     10;24;209
# 10                    11;26;498
# 11                    12;29;398
